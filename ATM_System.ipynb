# %%
pin = 2802
balance = 2500
choice = int(input("Cash deposit(1) or Cash Withdrawl(2)"))
if choice == 1:
  amount = int(input("enter amount to be deposited"))
  balance += amount
  print(f"Your Balance is {balance}")
elif choice == 2:
  Pin = int(input("Enter your PIN"))
  if Pin==pin:
    amount = int(input("Enter amount to be withdrawn"))
    if amount>balance:
      print("insufficient balance")
    else:
      balance-=amount
      print(f"your Balance is {balance}")
  else:
    print("incorrect pin")
else:
  print("invalid choice")
# Out:
# Cash deposit(1) or Cash Withdrawl(2)2
# Enter your PIN2802
# Enter amount to be withdrawn1500
# your Balance is 1000
